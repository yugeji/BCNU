# %%
import numpy as np
import pandas as pd
import pylab

import scipy
import scipy.cluster.hierarchy as sch
import scipy.stats as sp

from IPython.display import display

import utils
import pickle
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
def write_gene_list(degs, filename):
    with open('yuge/gene_lists/"+ filename + ".txt', 'w') as f:
        for probe in degs:
            f.write("%s\n" % probe)
    
#Plotting
import matplotlib.pyplot as plt

# from matplotlib.pyplot import figure
# figure(num=None, figsize=(8, 6), dpi=500, facecolor='w', edgecolor='k')

#Tools
import scanpy.api as sc
import anndata #really just using this, not scanpy
import gseapy as gp

# %% [markdown]
# # Load Data

# %%
chandni_anova_probes = ["201578_at","214203_s_at","219815_at","219695_at","201896_s_at","205157_s_at","212236_x_at","230606_at","235857_at","216748_at","201939_at","218346_s_at","1554367_at","220073_s_at","220756_s_at","1554547_at","204736_s_at","201286_at","204566_at","227816_at","209652_s_at","209290_s_at","229382_at","239332_at","210609_s_at","215407_s_at","231950_at","201834_at","219938_s_at","229245_at","218180_s_at","226124_at","229254_at","214297_at","226435_at","202686_s_at","209498_at","234644_x_at","219412_at","227522_at","218124_at","231115_at","1558368_s_at","226534_at","209462_at","234726_s_at","213375_s_at","214761_at","229030_at","240413_at","222354_at","218962_s_at","230330_at","218902_at","225055_at","231478_at","236641_at","240252_at","235352_at","238733_at","214745_at","232899_at","222958_s_at","210670_at","223179_at","218288_s_at","236245_at","1552599_at","1569318_at","220476_s_at","228128_x_at","243099_at","204962_s_at","229699_at","205569_at","242400_at","227020_at","221576_at","211163_s_at","211889_x_at","239988_at","210821_x_at","203845_at","239824_s_at","227345_at","226793_at","235200_at","206222_at","226363_at","211883_x_at","218657_at","206576_s_at","203409_at","242978_x_at","210605_s_at","225522_at","1555981_at","230632_at","219179_at","238454_at","209289_at","201061_s_at","236055_at","237063_at","224674_at","236036_at","205046_at","207194_s_at","209693_at","207566_at","228293_at","232077_s_at","208779_x_at","235627_at","206515_at","225470_at","226111_s_at","226649_at","235698_at","1007_s_at","227735_s_at","213029_at","244616_x_at","204224_s_at","208004_at","1566472_s_at","214760_at","238622_at","203081_at","1559226_x_at","227306_at","202055_at","235763_at","207565_s_at","230509_at","202794_at","239697_x_at","1559322_at","204857_at","221756_at","227102_at","227736_at","231017_at","201302_at","203764_at","1554256_a_at","218581_at","218512_at","232849_at","217104_at","236512_at","221258_s_at","218634_at","213658_at","1563498_s_at","214710_s_at","213996_at","203846_at","201887_at","223413_s_at","222291_at","206514_s_at","218769_s_at","218755_at","237891_at","224724_at","223204_at","207813_s_at","220295_x_at","210223_s_at","220416_at","1557114_a_at","203499_at","221864_at","205531_s_at","222577_at","201506_at","1552846_s_at","238134_at","209183_s_at","227134_at","207169_x_at","205093_at","1559224_at","216080_s_at","1560590_s_at","229145_at","226013_at","225525_at","235460_at","201930_at","226342_at","227564_at","215843_s_at","213884_s_at","215722_s_at","229810_at","212851_at","225300_at","201508_at","231019_x_at","201196_s_at","223174_at","224433_s_at","228033_at","230188_at","221577_x_at","208080_at","209375_at","202138_x_at","229868_s_at","1561082_at","1560531_at","203622_s
at","219889_at","226314_at","204080_at","229114_at","229999_at","230165_at","242088_at","219502_at","227333_at","1557422_at","217881_s_at","225357_s_at","218593_at","240627_x_at","213364_s_at","219340_s_at","221436_s_at","239725_at","235263_at","212334_at","209330_s_at","242972_at","200607_s_at","266_s_at","239764_at","214532_x_at","229852_at","209479_at","1553706_at","1568795_at","205393_s_at","219787_s_at","229331_at","200790_at","230108_at","242861_at","204755_x_at","200750_s_at","1554271_a_at","230205_at","219944_at","209653_at","208353_x_at","221640_s_at","233215_s_at","1557521_a_at","207008_at","225851_at","205447_s_at","1556690_s_at","224204_x_at","209361_s_at","203579_s_at","1552785_at","219467_at","221634_at","222388_s_at","227250_at","231041_at","1553960_at","209817_at","232946_s_at","204573_at","1552474_a_at","220049_s_at","212476_at","232245_at","218882_s_at","215011_at","1552737_s_at","225299_at","208974_x_at","203761_at","204312_x_at","200956_s_at","208023_at","200692_s_at","224800_at","226874_at","218403_at","224824_at","241321_at","1568920_at","231540_at","232296_s_at","232721_at","241418_at","1556434_at","219635_at","1554761_a_at","232309_at","211833_s_at","200788_s_at","230058_at","239587_at","1561660_at","224456_s_at",
"209771_x_at"]

# %%
celllines = ["4", "5", "13", "16"]

# %%
#need to sort here by treated and untreated
cellline = {
    "5": None, 
    "4": None, 
    "13": None, 
    "16": None
}
for i in cellline.keys():
    cellline[i] = pd.read_pickle("MicroarrayData/"+ i + "_processed.pkl")
    
# #rearrange columns of cell line 4, replicate 1 to match others
cols = cellline["4"].columns.tolist()
cols = [cols[-1]] + cols[:2] + cols[12:14] + cols[2:12] + cols[14:-1]
cellline["4"] = cellline["4"][cols]

# %%
#log normalize against the time 0 data
for line in cellline.items():
    df = line[1]
    #first replicate
    time_0 = df.iloc[:, 0]
    for sample in df.columns[1:15]:
        new_values = np.log2(df[sample].values/time_0.values) #normalize
        df[sample] = new_values
    #second replicate
    time_0 = df.iloc[:, 15]
    for sample in df.columns[16:]:
        new_values = np.log2(df[sample].values/time_0.values) #normalize
        df[sample] = new_values
    
    #drop the time zero values
    df.drop(df.columns[15], axis = 1, inplace = True)
    df.drop(df.columns[0], axis = 1, inplace = True)

# %%
#join the dataframes
all_celllines = pd.concat([cellline["4"], cellline["5"], cellline["13"], cellline["16"]], axis=1)
all_celllines.T.head()
# Out:
#                   1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 4_1_4_untreated    0.000866  0.033918 -0.024396  0.030163  -0.108362
# 4_1_4_treated     -0.044422  0.013748 -0.067415  0.008009  -0.156697
# 4_1_8_untreated    0.021753  0.017897 -0.070792 -0.004497  -0.149114
# 4_1_8_treated      0.088068  0.017736  0.014979  0.089892  -0.037626
# 4_1_12_untreated  -0.007723  0.016004 -0.044194  0.065746  -0.167638
#
#                    1294_at   1316_at   1320_at  1405_i_at   1431_at  \
# 4_1_4_untreated  -0.055406 -0.004063 -0.012417  -0.004118  0.102476
# 4_1_4_treated    -0.078221 -0.059900 -0.012999   0.005268  0.042311
# 4_1_8_untreated  -0.079147 -0.056187 -0.082915  -0.006591  0.061962
# 4_1_8_treated    -0.034097  0.002710  0.026034  -0.050696  0.156461
# 4_1_12_untreated -0.098851 -0.041107  0.015715  -0.026866  0.108194
#
#                        ...         AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  \
# 4_1_4_untreated        ...                     0.001585             -0.010977
# 4_1_4_treated          ...                     0.003700             -0.003940
# 4_1_8_untreated        ...                    -0.028269             -0.031889
# 4_1_8_treated          ...                    -0.022388             -0.034016
# 4_1_12_untreated       ...                     0.000266             -0.007447
#
#                   AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  \
# 4_1_4_untreated              0.003940            -0.000564       -0.011674
# 4_1_4_treated               -0.000641            -0.004846       -0.017027
# 4_1_8_untreated              0.000162             0.002188        0.008035
# 4_1_8_treated                0.005524            -0.000221        0.035886
# 4_1_12_untreated            -0.002659            -0.006081        0.019956
#
#                   AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 4_1_4_untreated        -0.011770       -0.050118        -0.040658
# 4_1_4_treated           0.017401       -0.021337        -0.038419
# 4_1_8_untreated        -0.014852       -0.044646        -0.093089
# 4_1_8_treated          -0.009137       -0.018200        -0.034215
# 4_1_12_untreated        0.010629       -0.081639        -0.092504
#
#                   AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 4_1_4_untreated         -0.041385        -0.036648
# 4_1_4_treated           -0.047188        -0.010945
# 4_1_8_untreated         -0.033375        -0.031647
# 4_1_8_treated           -0.045235         0.113618
# 4_1_12_untreated         0.005768         0.096386
#
# [5 rows x 54675 columns]

# %%
#gather into an anndata so we can move it around easily
adata = anndata.AnnData(all_celllines.T)
adata.obs["cellline"] = [c.split("_")[0] for c in adata.obs_names]
adata.obs["replicate"] = [c.split("_")[1] for c in adata.obs_names]
adata.obs["timepoint"] = [c.split("_")[2] for c in adata.obs_names]
adata.obs["treatment"] = [c.split("_")[3] for c in adata.obs_names]
adata
# Out:
# AnnData object with n_obs × n_vars = 112 × 54675
#     obs: 'cellline', 'replicate', 'timepoint', 'treatment'

# %% [markdown]
# TODO: there's no mention of replicates in the manuscript...

# %%
#helpful function for when you want to use the genes:
gene_list = pd.read_csv("MicroarrayData/gene_list.txt", sep=' ', header = None, index_col = 0, names = ["gene_id"])
probe_dict = gene_list.to_dict()["gene_id"]

def change_index_to_genes(dataframe):
    """
    Changes (in place) the row indices of a dataframe from gene IDs to gene names. Ignores rows where the gene ID is not mapped to a gene.
    """
    genes = []
    for g in dataframe.index.values:
        try:
            gene = gene_list[gene_list.affy_hg_u133_plus_2 == g].external_gene_name.values[0]
            genes.append(gene)
        except IndexError: 
            genes.append(g)

    dataframe.index = genes
    
def change_probes_to_genes(probes):
    """
    Given a list of probe set ids, returns the genes.
    """
    genes = []
    for p in probes:
        genes.appened(probe_dict[p])
    return genes

def change_probe_to_gene(probe):
    return probe_dict[probe]

# %%
#could run GSEA from here on these genes
def run_GSEA(dic):
    sig_ranked_dataframe = pd.DataFrame()
    sig_ranked_dataframe[0] = dic.keys()
    sig_ranked_dataframe[1] = list(dic.values())

    gene_set = 'GO_Biological_Process_2018'

    res = gp.prerank(rnk=sig_ranked_dataframe,
                                         gene_sets=gene_set,
                                         max_size = 1000,
                                         min_size = 15, #number of overlapping genes, I think
                                         processes= 32,
                                         permutation_num=1000, # reduce number to speed up test
                                         no_plot = True,
                                         outdir='gsea_plots/prerank_report_'+gene_set,format='png')
    return res

# %%
def filter_adata(adata, params):
    """
    Recursively filters an adata by certain observations. 
    Observations are specified in a list of tuples of (.obs, value). Multiple values can be specified in a list.
    """
    if not isinstance(params[0][1], list):
        value = [params[0][1]]
    else:
        value = params[0][1]
        
    new_adata = adata[adata.obs[params[0][0]].isin(value)]
    
    if len(params) > 1:
        new_adata = filter_adata(new_adata, params[1:])
    
    return new_adata

# %%
def overlap(a, b):
    print (len(list(set(a) & set(b))))

# %%
line_4_treated = filter_adata(adata, [("cellline", "4"), ("treatment", "treated")])
line_5_treated = filter_adata(adata, [("cellline", "5"), ("treatment", "treated")])
line_16_treated = filter_adata(adata, [("cellline", "16"), ("treatment", "treated")])
line_13_treated = filter_adata(adata, [("cellline", "13"), ("treatment", "treated")])

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Old Stuff

# %% [markdown]
# ### General ttest comparison of celllines to evaluate base level differences

# %%
#sensitive vs. sensitive
total = 0
for i in range(adata.shape[1]):
    total += np.abs(sp.ttest_ind(line_4_treated.X.T[i], line_5_treated.X.T[i])[0])
total
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fc629049f02d> in <module>()
#       2 total = 0
#       3 for i in range(adata.shape[1]):
# ----> 4     total += np.abs(sp.ttest_ind(line_4_treated.X.T[i], line_5_treated.X.T[i])[0])
#       5 total
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/scipy/stats/stats.py in ttest_ind(a, b, axis, equal_var, nan_policy)
#    4074
#    4075     if equal_var:
# -> 4076         df, denom = _equal_var_ttest_denom(v1, n1, v2, n2)
#    4077     else:
#    4078         df, denom = _unequal_var_ttest_denom(v1, n1, v2, n2)
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/scipy/stats/stats.py in _equal_var_ttest_denom(v1, n1, v2, n2)
#    3863 def _equal_var_ttest_denom(v1, n1, v2, n2):
#    3864     df = n1 + n2 - 2.0
# -> 3865     svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#    3866     denom = np.sqrt(svar * (1.0 / n1 + 1.0 / n2))
#    3867     return df, denom
#
# KeyboardInterrupt:

# %%
#resistant vs. resistant
total = 0
for i in range(adata.shape[1]):
    total += np.abs(sp.ttest_ind(line_16_treated.X.T[i], line_13_treated.X.T[i])[0])
total

# %%
#resistant vs. sensitive
total = 0
for i in range(adata.shape[1]):
    total += np.abs(sp.ttest_ind(line_16_treated.X.T[i], line_4_treated.X.T[i])[0])
total

# %%
#resistant vs. sensitive
total = 0
for i in range(adata.shape[1]):
    total += np.abs(sp.ttest_ind(line_13_treated.X.T[i], line_4_treated.X.T[i])[0])
total

# %%
#resistant vs. sensitive
total = 0
for i in range(adata.shape[1]):
    total += np.abs(sp.ttest_ind(line_16_treated.X.T[i], line_5_treated.X.T[i])[0])
total
# Out:
# 227981.70780377014

# %%
#resistant vs. sensitive
total = 0
for i in range(adata.shape[1]):
    total += np.abs(sp.ttest_ind(line_13_treated.X.T[i], line_5_treated.X.T[i])[0])
total
# Out:
# 269881.9044761192

# %% [markdown]
# ### look at which genes are very different between lines 13 and 16 in comparison to 5 and 4

# %% [markdown]
# In Chandni's original paper, she visualized 10k probesets that varied over either time, treatment, or cell line. Here I am only looking at those that varied more from resistant cell lines

# %%
differences = {}
for i in range(adata.shape[1]):
    similar = sp.ttest_ind(line_5_treated.X.T[i], line_4_treated.X.T[i])[0]
    different = sp.ttest_ind(line_13_treated.X.T[i], line_4_treated.X.T[i])[0]
    differences[adata.var_names[i]] = similar-different

# %%
vals = list(differences.values())
plt.hist(vals, bins=50)
mean = np.mean(vals)
std = np.std(vals)
print (mean, std)
# Out:
# 3.902199106441154 7.0207250712517855

# %%
highly_deg = {}
for k in differences.keys():
    if differences[k] > mean + 1*std or differences[k] < mean - 1*std:
        highly_deg[k] = differences[k]

# %%
len(highly_deg)
# Out:
# 6332

# %% [markdown]
# ## Heatmap of DEG genes

# %%
def gene_heatmap(adata, genes, label = "timepoint"):
    """
    What to label the yticks by. Can be either cellline, replicate, timepoint, or treatment, but must be in adata.obs.
    """
    #determine range of values before filtering to maintain consistency
    colormap_range = np.max([np.max(adata.X), np.abs(np.min(adata.X))])
    
    filtered_data = adata[:, genes].X
#     colormap_range = np.max([np.max(filtered_data), np.abs(np.min(filtered_data))])
    #plot
    plt.figure(figsize=(18,int(filtered_data.shape[0]/3)))
    plt.imshow(filtered_data, interpolation='nearest', cmap = "seismic", vmin = -colormap_range, vmax = colormap_range, aspect='auto')
    
    #labeling
    values = adata.obs[label].values
    plt.yticks(np.arange(filtered_data.shape[0]), values, rotation="horizontal")
    plt.colorbar()
    plt.title("cell line " + str(adata.obs["cellline"].values[0]) + ", replicate " + str(adata.obs["replicate"].values[0]) + ", " + adata.obs["treatment"].values[0])
    plt.show()
    
def filter_anova_result(gene_tables, threshold = .05):
    if len(gene_tables) == 0:
        raise Exception("Gene table is empty.")
    
    degs_dict = {}
    #filter out those with pvalue < threshold
    for gene in gene_tables.keys():
        table = gene_tables[gene]
        pval = table["PR(>F)"].values[-2]
        if pval < threshold:
            degs_dict[gene] = pval
    
    if len(degs_dict) == 0:
        raise Exception("Threshold is too low and no genes passed.")
    
    #give the dictionary order by p-value
    sorted_genes = [x[0] for x in sorted(list(degs_dict.items()), key = lambda x : x[1])]
    better_dict = {}
    for gene in sorted_genes:
        better_dict[gene] = degs_dict[gene]

    print (len(better_dict))
    return better_dict

# %%
rep1_untreated = filter_adata(adata, [("replicate", "1"), ("cellline", "4"), ("treatment", "untreated")])
gene_heatmap(rep1_untreated, chandni_anova_probes, label="timepoint")
rep1_treated = filter_adata(adata, [("cellline", "4"), ("treatment", "treated")])
gene_heatmap(rep1_treated, chandni_anova_probes, label="timepoint")

print ("Cell line 13")
rep1_untreated = filter_adata(adata, [("cellline", "13"), ("treatment", "untreated")])
gene_heatmap(rep1_untreated, chandni_anova_probes, label="timepoint")
rep1_treated = filter_adata(adata, [("cellline", "13"), ("treatment", "treated")])
gene_heatmap(rep1_treated, chandni_anova_probes, label="timepoint")
# Out:
# Cell line 13

# %%
#with my own anova degs
gene_table = load_obj("anova2_gene_table")

# %%
genes = list(filter_anova_result(gene_table, threshold = .01).keys())
# genes = chandni_anova_probes #list(degs.keys()) #

for cl in celllines:
    for rep in ["1", "2"]:
        rep1_untreated = filter_adata(adata, [("replicate", rep), ("cellline", cl), ("treatment", "untreated")])
        gene_heatmap(rep1_untreated, genes, label="timepoint")
        rep1_treated = filter_adata(adata, [("replicate", rep), ("cellline", cl), ("treatment", "treated")])
        gene_heatmap(rep1_treated, genes, label="timepoint")
# Out:
# 556

# %%
overlap(degs, chandni_anova_probes)
# Out:
# 16

# %%
write_gene_list(list(degs.keys()), "anova_nonnormed_gene_list")

# %% [markdown]
# ### Plotting

# %%
degs = chandni_anova_probes

# %% [markdown]
# Even using Chandni's genes, the python plot doesn't look very different...

# %%
#loading
gene_tables = load_obj("anova2_probeset_normed2") #load_obj("anova_results")

# %%
#sorting my dictionary by p-value because Chandni's probes are also sorted by p-value
degs = [x[0] for x in sorted(list(degs_dict.items()), key = lambda x : x[1])]

# %%
#check for overlap between the gene sets
overlap(degs, chandni_anova_proves)
# Out:
# 35

# %% [markdown]
# #### formatted like Figure 3.16, Mock Treated vs. Treated

# %%
#we want them in this structure: mock treated-> celllines (x4) -> time points, treated celllines (x4) -> time points,
treated_heatmap = []
for line in celllines:
    line_treated = filter_adata(adata, [("cellline", line), ("treatment", "treated")])
    line_treated_filtered = line_treated[:, degs] #list(highly_deg.keys())]
    if len(treated_heatmap) == 0:
        treated_heatmap = line_treated_filtered.X
    else:
        treated_heatmap += line_treated_filtered.X

untreated_heatmap = []
for line in celllines:
    line_treated = filter_adata(adata, [("cellline", line), ("treatment", "untreated")])
    line_treated_filtered = line_treated[:, degs]#list(highly_deg.keys())]
    if len(untreated_heatmap) == 0:
        untreated_heatmap = line_treated_filtered.X
    else:
        untreated_heatmap += line_treated_filtered.X

# %%
line_4_treated.obs["timepoint"] #the order the variables show up in
# Out:
# 4_1_4_treated      4
# 4_1_8_treated      8
# 4_1_12_treated    12
# 4_1_24_treated    24
# 4_1_36_treated    36
# 4_1_48_treated    48
# 4_1_72_treated    72
# 4_2_4_treated      4
# 4_2_8_treated      8
# 4_2_12_treated    12
# 4_2_24_treated    24
# 4_2_36_treated    36
# 4_2_48_treated    48
# 4_2_72_treated    72
# Name: timepoint, dtype: object

# %%
#run this to see raw 56k genes, not DEGS
treated_heatmap = filter_adata(adata, [("treatment", "treated")]).X
untreated_heatmap = filter_adata(adata, [("treatment", "untreated")]).X

# %%
plt.figure(figsize=(18,6))
plt.imshow(treated_heatmap, interpolation='nearest', cmap="YlGn", vmin = -1.7, vmax = 2.2, aspect='auto')
plt.colorbar()
plt.show()

# %%
treated_heatmap
# Out:
# ArrayView([[-0.12370933,  0.13361536, -0.06394439, ..., -0.27110052,
#             -0.17101772, -0.34607244],
#            [-0.00433868,  0.16776544,  0.15242414, ..., -0.29166582,
#             -0.22716713, -0.17382911],
#            [ 0.15344675,  0.6020541 ,  0.10078736, ..., -0.24613173,
#             -0.15698858, -0.07473863],
#            ...,
#            [ 0.31306443,  0.67285985,  0.35506865, ...,  0.16497593,
#             -0.18899678,  0.17137708],
#            [ 0.42811152,  0.31678468,  0.35024852, ..., -0.0673086 ,
#             -0.23293716,  0.18858747],
#            [ 0.21559113,  0.5839228 ,  0.37927276, ...,  0.05648213,
#             -0.13310908,  0.17488867]], dtype=float32)

# %%
plt.figure(figsize=(18,6))
plt.imshow(untreated_heatmap, interpolation='nearest', cmap="YlGn", vmin = -1.7, vmax = 2.2, aspect='auto')
plt.colorbar()
plt.show()

# %% [markdown]
# Doesn't look different, rip.
#
# Also note that Chandni said max expression was at 4.2, where I'm getting 2.2 for the same genes that she use.

# %% [markdown]
# #### formatted like Figure 3.17, Sensitive vs. Resistant

# %%
for line in celllines:
    mock_4 = filter_adata(adata, [("cellline", line), ("treatment", "untreated")])[:, degs]
    #arrange replicates so the same time points are next to each other
    mock = []
    for i in range(7):
        mock.append(mock_4.X[i])
        mock.append(mock_4.X[i+7])
    
    #plot
    print ("celline ", line)
    
    plt.figure(figsize=(18, 4))
#     plt.imshow(np.array(mock), interpolation='nearest', cmap = "seismic", vmin = -1.2, vmax = 1.2, aspect='auto')
#     plt.imshow(mock_4.X[:7], interpolation='nearest', cmap = "seismic", vmin = -1.2, vmax = 1.2, aspect='auto')
    plt.imshow(mock_4.X[7:], interpolation='nearest', cmap = "seismic", vmin = -1.2, vmax = 1.2, aspect='auto')    

    plt.yticks(np.arange(len(mock_4.obs["timepoint"][:7])), [str(x) + " hrs" for x in mock_4.obs["timepoint"].values[:7]], rotation="horizontal")
    plt.colorbar()
    plt.show()
    
    treated_4 = filter_adata(adata, [("cellline", line), ("treatment", "treated")])[:, degs]
    #plot
    plt.figure(figsize=(4,18))
    plt.imshow(treated_4.X[:7].T, interpolation='nearest', cmap = "seismic", vmin = -1.2, vmax = 1.2, aspect='auto')
    
    plt.xticks(np.arange(len(mock_4.obs["timepoint"][:7])), [str(x) + " hrs" for x in mock_4.obs["timepoint"].values[:7]], rotation="horizontal")
    plt.colorbar()
    plt.show()
# Out:
# celline  4
# celline  5
# celline  13
# celline  16

# %% [markdown]
# #### Run GSEA

# %%
res = run_GSEA(highly_deg)
res.res2d
# Out:
#                                                           es       nes  \
# Term
# defense response to bacterium (GO:0042742)         -0.568957 -2.510250
# positive regulation of cytokine production (GO:... -0.462352 -1.926061
# central nervous system development (GO:0007417)     0.559909  1.972522
# positive regulation of lymphocyte activation (G... -0.413171 -1.628071
# antigen receptor-mediated signaling pathway (GO... -0.335125 -1.664089
# phagocytosis (GO:0006909)                          -0.386331 -1.533745
# positive regulation of multicellular organismal... -0.319039 -1.319915
# regulation of angiogenesis (GO:0045765)            -0.276949 -1.282040
# negative regulation of nucleic acid-templated t... -0.275528 -1.291762
# negative regulation of cellular macromolecule b... -0.287960 -1.330907
# regulated exocytosis (GO:0045055)                  -0.287389 -1.237179
# negative regulation of gene expression (GO:0010... -0.279326 -1.348186
# negative regulation of cell proliferation (GO:0...  0.874154  0.920058
# protein phosphorylation (GO:0006468)                0.839031  0.928114
# positive regulation of MAPK cascade (GO:0043410)    0.064295  0.938381
# negative regulation of signal transduction (GO:...  0.982090  0.987618
#
#                                                     geneset_size  \
# Term
# defense response to bacterium (GO:0042742)                   242
# positive regulation of cytokine production (GO:...           221
# central nervous system development (GO:0007417)              218
# positive regulation of lymphocyte activation (G...           105
# antigen receptor-mediated signaling pathway (GO...           258
# phagocytosis (GO:0006909)                                    136
# positive regulation of multicellular organismal...           203
# regulation of angiogenesis (GO:0045765)                      178
# negative regulation of nucleic acid-templated t...           445
# negative regulation of cellular macromolecule b...           513
# regulated exocytosis (GO:0045055)                            149
# negative regulation of gene expression (GO:0010...           619
# nervous system development (GO:0007399)                      456
# cellular response to oxygen-containing compound...           275
# chemical synaptic transmission (GO:0007268)                  290
# cellular response to lipid (GO:0071396)                      179
# positive regulation of macromolecule metabolic ...           277
# negative regulation of transcription, DNA-templ...           814
# platelet degranulation (GO:0002576)                          125
# regulation of cell migration (GO:0030334)                    317
# negative regulation of programmed cell death (G...           409
# regulation of apoptotic process (GO:0042981)                 816
# cellular response to organic substance (GO:0071...           134
# receptor-mediated endocytosis (GO:0006898)                   189
# positive regulation of ERK1 and ERK2 cascade (G...           202
# cellular response to tumor necrosis factor (GO:...           195
# cellular protein modification process (GO:0006464)          1002
# activation of protein kinase activity (GO:0032147)           234
# regulation of immune response (GO:0050776)                   252
# positive regulation of cell proliferation (GO:0...           425
# ...                                                          ...
# regulation of transcription from RNA polymerase...          1479
# regulation of MAPK cascade (GO:0043408)                      204
# transcription from RNA polymerase II promoter (...           486
# phosphorylation (GO:0016310)                                 387
# regulation of nucleic acid-templated transcript...           608
# positive regulation of protein kinase B signali...           128
# endocytosis (GO:0006897)                                     264
# regulation of cell proliferation (GO:0042127)                741
# protein ubiquitination (GO:0016567)                          507
# regulation of protein kinase B signaling (GO:00...           164
# inflammatory response (GO:0006954)                           253
# positive regulation of gene expression (GO:0010...           772
# positive regulation of protein phosphorylation ...           413
# positive regulation of cellular process (GO:004...           520
# positive regulation of cell migration (GO:0030335)           222
# negative regulation of apoptotic process (GO:00...           486
# regulation of signal transduction (GO:0009966)               234
# cellular protein localization (GO:0034613)                   328
# transmembrane receptor protein tyrosine kinase ...           397
# positive regulation of nucleic acid-templated t...           503
# positive regulation of cell motility (GO:2000147)            180
# negative regulation of transcription from RNA p...           566
# regulation of transcription, DNA-templated (GO:...          1599
# positive regulation of signal transduction (GO:...           207
# cellular protein metabolic process (GO:0044267)              485
# regulation of cellular macromolecule biosynthet...           632
# negative regulation of cell proliferation (GO:0...           364
# protein phosphorylation (GO:0006468)                         471
# positive regulation of MAPK cascade (GO:0043410)             290
# negative regulation of signal transduction (GO:...           284
#
#                                                     matched_size  \
# Term
# defense response to bacterium (GO:0042742)                    18
# positive regulation of cytokine production (GO:...            17
# central nervous system development (GO:0007417)               16
# positive regulation of lymphocyte activation (G...            15
# antigen receptor-mediated signaling pathway (GO...            25
# phagocytosis (GO:0006909)                                     15
# positive regulation of multicellular organismal...            17
# regulation of angiogenesis (GO:0045765)                       21
# negative regulation of nucleic acid-templated t...            22
# negative regulation of cellular macromolecule b...            21
# regulated exocytosis (GO:0045055)                             18
# negative regulation of gene expression (GO:0010...            26
# nervous system development (GO:0007399)                       33
# cellular response to oxygen-containing compound...            19
# chemical synaptic transmission (GO:0007268)                   15
# cellular response to lipid (GO:0071396)                       15
# positive regulation of macromolecule metabolic ...            25
# negative regulation of transcription, DNA-templ...            45
# platelet degranulation (GO:0002576)                           15
# regulation of cell migration (GO:0030334)                     30
# negative regulation of programmed cell death (G...            23
# regulation of apoptotic process (GO:0042981)                  38
# cellular response to organic substance (GO:0071...            15
# receptor-mediated endocytosis (GO:0006898)                    15
# positive regulation of ERK1 and ERK2 cascade (G...            23
# cellular response to tumor necrosis factor (GO:...            16
# cellular protein modification process (GO:0006464)            54
# activation of protein kinase activity (GO:0032147)            15
# regulation of immune response (GO:0050776)                    29
# positive regulation of cell proliferation (GO:0...            29
# ...                                                          ...
# regulation of transcription from RNA polymerase...            69
# regulation of MAPK cascade (GO:0043408)                       15
# transcription from RNA polymerase II promoter (...            18
# phosphorylation (GO:0016310)                                  21
# regulation of nucleic acid-templated transcript...            25
# positive regulation of protein kinase B signali...            19
# endocytosis (GO:0006897)                                      17
# regulation of cell proliferation (GO:0042127)                 61
# protein ubiquitination (GO:0016567)                           16
# regulation of protein kinase B signaling (GO:00...            19
# inflammatory response (GO:0006954)                            29
# positive regulation of gene expression (GO:0010...            46
# positive regulation of protein phosphorylation ...            31
# positive regulation of cellular process (GO:004...            27
# positive regulation of cell migration (GO:0030335)            19
# negative regulation of apoptotic process (GO:00...            34
# regulation of signal transduction (GO:0009966)                24
# cellular protein localization (GO:0034613)                    15
# transmembrane receptor protein tyrosine kinase ...            32
# positive regulation of nucleic acid-templated t...            30
# positive regulation of cell motility (GO:2000147)             17
# negative regulation of transcription from RNA p...            37
# regulation of transcription, DNA-templated (GO:...            68
# positive regulation of signal transduction (GO:...            19
# cellular protein metabolic process (GO:0044267)               23
# regulation of cellular macromolecule biosynthet...            25
# negative regulation of cell proliferation (GO:0...            36
# protein phosphorylation (GO:0006468)                          26
# positive regulation of MAPK cascade (GO:0043410)              31
# negative regulation of signal transduction (GO:...            21
#
#                                                                                                 genes
# Term
# defense response to bacterium (GO:0042742)          LYPD8,IGHV3-33,GNLY,IL12B,IGHV4-61,IGHD,IGHV3-...
# positive regulation of cytokine production (GO:...  FFAR2,CCR7,IL12B,RGCC,IL10,GBP5,CSF2,AFAP1L2,H...
# central nervous system development (GO:0007417)     CELSR1,NNAT,FYN,CDH2,B3GNT5,PPP1R17,GRIN2A,APO...
# positive regulation of lymphocyte activation (G...  SIRPB1,CCL2,CCR7,IGHV3-33,IL12B,IGHV4-61,IGHD,...
# antigen receptor-mediated signaling pathway (GO...  FYN,THEMIS,CD4,HLA-DRB4,BTNL9,PSMA8,GRAP2,IGHV...
# positive regulation of signal transduction (GO:...  HHEX,ITGB3,CTBP2,CHRNA7,RAB34,ROBO1,NOV,KAT2B,...
# cellular protein metabolic process (GO:0044267)     FN1,CDH2,ADORA2B,IGFBP3,MFGE8,IGFBP4,ST3GAL1,G...
# regulation of cellular macromolecule biosynthet...  ZNF677,INSR,ESR1,ZNF300,ZNF665,ZNF610,NR3C1,ZN...
# negative regulation of cell proliferation (GO:0...  NELL1,ADARB1,KLF11,PPARG,CTBP2,CCL23,IGFBP3,CD...
# protein phosphorylation (GO:0006468)                PRKCH,FYN,CCL2,INSR,IGFBP3,MERTK,ULK2,NUAK1,CS...
# positive regulation of MAPK cascade (GO:0043410)    TNFRSF10A,CCL18,CCL2,INSR,GCNT2,TNFRSF1A,TNFRS...
# negative regulation of signal transduction (GO:...  HHEX,INSR,IGFBP3,MERTK,HBEGF,SPRY2,CSF1R,ADAMT...
#
# [85 rows x 7 columns]

# %%
#should probably also run ANOVA like in the old analysis

# %%
#check for genes that associated with BCNU in the literature
"FOXO1" in differences.keys()
# Out:
# True

# %%
differences["FOXO1"] #this is pretty low?
# Out:
# 3.94320770187751

# %% [markdown]
# I'm not sure if looking at different levels of transcription will tell me much. I think I need to compare untreated to treated, and then compare the difference of that distribution.

# %%
line_4_treated_timed = filter_adata(adata, [("cellline", "4"), ("treatment", "treated"), ("timepoint", ["4", "8", "12", "24", "48"])])
line_5_treated_timed = filter_adata(adata, [("cellline", "5"), ("treatment", "treated"), ("timepoint", ["4", "8", "12", "24", "48"])])
line_16_treated_timed = filter_adata(adata, [("cellline", "16"), ("treatment", "treated"), ("timepoint", ["4", "8", "12", "24", "48"])])
line_13_treated_timed = filter_adata(adata, [("cellline", "13"), ("treatment", "treated"), ("timepoint", ["4", "8", "12", "24", "48"])])

# %%
line_4_untreated = filter_adata(adata, [("cellline", "4"), ("treatment", "untreated"), ("timepoint", ["4", "8", "12", "24", "48"])])
line_5_untreated = filter_adata(adata, [("cellline", "5"), ("treatment", "untreated"), ("timepoint", ["4", "8", "12", "24", "48"])])
line_16_untreated = filter_adata(adata, [("cellline", "16"), ("treatment", "untreated"), ("timepoint", ["4", "8", "12", "24", "48"])])
line_13_untreated = filter_adata(adata, [("cellline", "13"), ("treatment", "untreated"), ("timepoint", ["4", "8", "12", "24", "48"])])

# %%
#look at which genes are very different between lines 13 and 4 in comparison to 5 and 4
differences2 = {}
for i in range(adata.shape[1]):
    line_5 = np.array(line_5_treated_timed.X.T[i])-np.array(line_5_untreated.X.T[i])
    line_4 = np.array(line_4_treated_timed.X.T[i])-np.array(line_4_untreated.X.T[i])
    line_13 = np.array(line_13_treated_timed.X.T[i])-np.array(line_13_untreated.X.T[i])
    
    similar = sp.ttest_ind(line_5, line_4)[0]
    different = sp.ttest_ind(line_13, line_4)[0]
    differences2[adata.var_names[i]] = similar-different

# %%
vals = list(differences2.values())
plt.hist(vals, bins=50)
mean = np.mean(vals)
std = np.std(vals)
print (mean, std)
# Out:
# -0.14400058932290274 1.2204791048260701

# %%
highly_deg2 = {}
for k in differences2.keys():
    if differences2[k] > mean + 2*std or differences2[k] < mean - 2*std:
        highly_deg2[k] = differences2[k]

# %%
len(highly_deg2)
# Out:
# 1674

# %%
res = run_GSEA(highly_deg2)
res.res2d
# Out:
#                                                           es       nes  \
# Term
# mRNA splicing, via spliceosome (GO:0000398)        -0.435857 -2.254414
# rRNA processing (GO:0006364)                       -0.372640 -1.795491
# cellular protein metabolic process (GO:0044267)    -0.286943 -1.850128
# rRNA metabolic process (GO:0016072)                -0.393686 -1.809879
# negative regulation of apoptotic process (GO:00... -0.314210 -1.813562
# gene expression (GO:0010467)                       -0.283387 -1.854963
# negative regulation of programmed cell death (G... -0.367073 -1.945224
# translation (GO:0006412)                           -0.384416 -1.869546
# ribosome biogenesis (GO:0042254)                   -0.370204 -1.894736
# ncRNA processing (GO:0034470)                      -0.353273 -1.734767
# RNA splicing, via transesterification reactions... -0.408516 -1.964305
# phosphorylation (GO:0016310)                       -0.331363 -1.637698
# regulation of cell migration (GO:0030334)          -0.341899 -1.645259
# regulation of mitotic cell cycle phase transiti... -0.343260 -1.614444
# mRNA processing (GO:0006397)                       -0.408516 -1.976255
# regulation of apoptotic process (GO:0042981)       -0.214364 -1.568405
# cellular protein modification process (GO:0006464) -0.180090 -1.496322
# RNA metabolic process (GO:0016070)                 -0.321136 -1.507230
# protein stabilization (GO:0050821)                 -0.285227 -1.416416
# protein modification by small protein conjugati... -0.243497 -1.357669
# positive regulation of intracellular protein tr... -0.298461 -1.364520
# protein polyubiquitination (GO:0000209)            -0.267900 -1.315926
# cellular macromolecule biosynthetic process (GO... -0.241068 -1.334523
# intracellular protein transport (GO:0006886)       -0.245009 -1.319780
# protein modification by small protein removal (... -0.229222 -1.213975
# proteasome-mediated ubiquitin-dependent protein... -0.218174 -1.203235
# protein deubiquitination (GO:0016579)              -0.226536 -1.167159
# regulation of translation (GO:0006417)             -0.253124 -1.216095
# endocytosis (GO:0006897)                           -0.250758 -1.170181
# post-translational protein modification (GO:004... -0.205346 -1.176207
# ...                                                      ...       ...
# positive regulation of macromolecule metabolic ... -0.131700 -0.683245
# positive regulation of cell migration (GO:0030335) -0.136739 -0.662217
# positive regulation of intracellular signal tra...  0.162701  0.936070
# regulation of transcription from RNA polymerase...  0.091453  0.878344
# transmembrane receptor protein tyrosine kinase ...  0.172702  0.917286
# proteasomal protein catabolic process (GO:0010498)  0.153545  0.804766
# negative regulation of nucleic acid-templated t...  0.216323  1.308728
# positive regulation of gene expression (GO:0010...  0.116427  0.885529
# peptidyl-lysine modification (GO:0018205)           0.172851  0.838495
# positive regulation of multicellular organismal... -0.142254 -0.611429
# positive regulation of transcription from RNA p...  0.085350  0.663694
# transmembrane transport (GO:0055085)                0.129576  0.681746
# cellular response to DNA damage stimulus (GO:00...  0.132138  0.806325
# chemical synaptic transmission (GO:0007268)         0.186969  0.889503
# regulation of phosphorylation (GO:0042325)          0.181206  0.815526
# plasma membrane bounded cell projection assembl...  0.166243  0.739033
# regulation of phosphorylation (GO:0042325)                   120
# plasma membrane bounded cell projection assembl...           242
# ubiquitin-dependent protein catabolic process (...           342
# cellular protein localization (GO:0034613)                   328
# regulation of intracellular signal transduction...           423
# positive regulation of transcription, DNA-templ...          1121
# cilium assembly (GO:0060271)                                 289
# regulation of gene expression (GO:0010468)                  1038
# organelle assembly (GO:0070925)                              377
# regulation of cellular macromolecule biosynthet...           632
# regulation of cell proliferation (GO:0042127)                741
# negative regulation of cellular macromolecule b...           513
# positive regulation of nucleic acid-templated t...           503
# vesicle-mediated transport (GO:0016192)                      411
# regulation of transcription, DNA-templated (GO:...          1599
# endosomal transport (GO:0016197)                             230
#
#                                                     matched_size  \
# Term
# mRNA splicing, via spliceosome (GO:0000398)                   23
# rRNA processing (GO:0006364)                                  19
# cellular protein metabolic process (GO:0044267)               37
# rRNA metabolic process (GO:0016072)                           18
# negative regulation of apoptotic process (GO:00...            30
# gene expression (GO:0010467)                                  41
# negative regulation of programmed cell death (G...            24
# translation (GO:0006412)                                      21
# ribosome biogenesis (GO:0042254)                              22
# ncRNA processing (GO:0034470)                                 20
# RNA splicing, via transesterification reactions...            19
# phosphorylation (GO:0016310)                                  21
# regulation of cell migration (GO:0030334)                     20
# regulation of mitotic cell cycle phase transiti...            19
# mRNA processing (GO:0006397)                                  19
# regulation of apoptotic process (GO:0042981)                  55
# cellular protein modification process (GO:0006464)            69
# RNA metabolic process (GO:0016070)                            18
# protein stabilization (GO:0050821)                            20
# protein modification by small protein conjugati...            28
# positive regulation of intracellular protein tr...            17
# protein polyubiquitination (GO:0000209)                       20
# cellular macromolecule biosynthetic process (GO...            27
# intracellular protein transport (GO:0006886)                  25
# protein modification by small protein removal (...            24
# proteasome-mediated ubiquitin-dependent protein...            26
# protein deubiquitination (GO:0016579)                         22
# regulation of translation (GO:0006417)                        20
# endocytosis (GO:0006897)                                      18
# post-translational protein modification (GO:004...            29
# ...                                                          ...
# positive regulation of macromolecule metabolic ...            23
# positive regulation of cell migration (GO:0030335)            19
# positive regulation of intracellular signal tra...            26
# regulation of transcription from RNA polymerase...            90
# transmembrane receptor protein tyrosine kinase ...            23
# proteasomal protein catabolic process (GO:0010498)            22
# negative regulation of nucleic acid-templated t...            29
# positive regulation of gene expression (GO:0010...            48
# peptidyl-lysine modification (GO:0018205)                     18
# positive regulation of multicellular organismal...            15
# positive regulation of transcription from RNA p...            52
# transmembrane transport (GO:0055085)                          21
# cellular response to DNA damage stimulus (GO:00...            30
# chemical synaptic transmission (GO:0007268)                   17
# regulation of phosphorylation (GO:0042325)                    15
# plasma membrane bounded cell projection assembl...            15
# ubiquitin-dependent protein catabolic process (...            29
# cellular protein localization (GO:0034613)                    20
# regulation of intracellular signal transduction...            21
# positive regulation of transcription, DNA-templ...            67
# cilium assembly (GO:0060271)                                  17
# regulation of gene expression (GO:0010468)                    65
# organelle assembly (GO:0070925)                               18
# regulation of cellular macromolecule biosynthet...            35
# regulation of cell proliferation (GO:0042127)                 45
# negative regulation of cellular macromolecule b...            34
# positive regulation of nucleic acid-templated t...            23
# vesicle-mediated transport (GO:0016192)                       24
# regulation of transcription, DNA-templated (GO:...           102
# endosomal transport (GO:0016197)                              18
#
#                                                                                                 genes
# Term
# mRNA splicing, via spliceosome (GO:0000398)         ESS2,RBMX,RBPMS,SNU13,DHX9,GPKOW,SUGP1,PRMT5,E...
# rRNA processing (GO:0006364)                        RPL24,RPL27,RPS19,RPS13,SNU13,UTP6,UTP11,EIF6,...
# cellular protein metabolic process (GO:0044267)     HSPG2,RPL24,RPL27,TXN,RABGGTA,RPS19,RPS13,PNPL...
# rRNA metabolic process (GO:0016072)                 RPL24,RPL27,RPS19,RPS13,SNU13,UTP6,UTP11,UTP20...
# negative regulation of apoptotic process (GO:00...  NR4A2,RHBDD1,HMGA2,DDAH2,HIGD2A,CRLF1,PIDD1,KL...
# gene expression (GO:0010467)                        NR4A2,RPL24,RPL27,TOPORS,RPS19,RPS13,LMF2,SMG1...
# negative regulation of programmed cell death (G...  RHBDD1,HMGA2,DDAH2,HIGD2A,PIDD1,TOPORS,CIB1,EP...
# translation (GO:0006412)                            RPL24,EEF2,RPL27,RPS19,RPS13,MRPS7,SNU13,TARS2...
# ribosome biogenesis (GO:0042254)                    RPL24,RPL27,RPS19,RPS13,ZNF658,SNU13,UTP6,UTP1...
# ncRNA processing (GO:0034470)                       RPL24,RPL27,RPS19,RPS13,SMAD1,SNU13,UTP6,UTP11...
# RNA splicing, via transesterification reactions...  ESS2,RBMX,RBPMS,SNU13,DHX9,GPKOW,SUGP1,EIF4A3,...
# phosphorylation (GO:0016310)                        IDNK,LATS2,TGFBR1,STK19,JAK1,FGR,ICK,PRKCI,TAO...
# regulation of cell migration (GO:0030334)           HACE1,TGFBR1,CXCL16,CIB1,CEACAM1,EPPK1,FGR,CSF...
# regulation of mitotic cell cycle phase transiti...  ANAPC16,XPC,NINL,UBB,PSMD11,UBE2C,PSMC3,PSMA7,...
# mRNA processing (GO:0006397)                        ESS2,RBMX,RBPMS,SNU13,DHX9,GPKOW,SUGP1,EIF4A3,...
# regulation of apoptotic process (GO:0042981)        BBC3,CIDEC,BAX,LATS2,RHBDD1,HMGA2,REST,DDAH2,H...
# cellular protein modification process (GO:0006464)  SPSB3,BTBD6,LATS2,RHBDD1,IVL,PHPT1,TGFBR1,PI3,...
# RNA metabolic process (GO:0016070)                  PCNA,PABPC3,RBMX,RBPMS,ZC3H12A,DHX9,MPHOSPH10,...
# protein stabilization (GO:0050821)                  CDKN1A,DVL3,PIN1,ATP1B1,LAMP2,WDR81,SUMO1,CCT3...
# protein modification by small protein conjugati...  PDZD4,PCNA,HACE1,ANAPC16,BCL10,TOPORS,SUMO1,UB...
# positive regulation of intracellular protein tr...  TOMM7,ITGAX,CIB1,ATG13,PRELID3A,ZC3H12A,ANK3,U...
# protein polyubiquitination (GO:0000209)             HACE1,TOPORS,SHARPIN,DTX3L,UBB,FBXO6,PSMD11,UB...
# cellular macromolecule biosynthetic process (GO...  NR4A2,RPL24,EEF2,RMI2,RPL27,TOPORS,RPS19,RPS13...
# intracellular protein transport (GO:0006886)        STX16-NPEPL1,RAB33B,RAB40C,LAMP2,RIC1,TBC1D13,...
# protein modification by small protein removal (...  USP35,KAT2B,TGFBR1,IL33,COPS7B,UBB,ZC3H12A,SMA...
# proteasome-mediated ubiquitin-dependent protein...  SPSB3,BTBD6,ANAPC16,TOPORS,SHARPIN,UBB,FBXO6,N...
# protein deubiquitination (GO:0016579)               USP35,KAT2B,TGFBR1,IL33,UBB,ZC3H12A,SMAD1,USP2...
# regulation of translation (GO:0006417)              BTG2,RPS27L,EEF2,RBM4B,EIF4G3,NUP188,DHX9,LARP...
# endocytosis (GO:0006897)                            IGKC,HSPG2,MICALL1,EEA1,IGKV3-20,GAK,HOOK2,CXC...
# post-translational protein modification (GO:004...  SPSB3,BTBD6,RHBDD1,RABGGTA,FN3KRP,PNPLA2,COPS7...
# ...                                                                                               ...
# positive regulation of macromolecule metabolic ...  HMGA2,ACTA2,TGFBR1,KLF4,DTX3L,SCRIB,PTPN22,ZC3...
# positive regulation of cell migration (GO:0030335)  DMTN,TGFBR1,INSL3,BMPR2,CXCL16,CIB1,MADCAM1,FG...
# positive regulation of intracellular signal tra...  BAX,RELN,TGFBR1,BCL10,IL11,TXN,SHARPIN,PMAIP1,...
# regulation of transcription from RNA polymerase...  PRDM1,WBP2,CIC,NR4A2,CDKN1A,IRF1,RFX7,ZNF76,GP...
# transmembrane receptor protein tyrosine kinase ...  ITGAV,GPRIN1,TIA1,BRK1,BMPR2,EPHB1,ATP6V1F,PGF...
# proteasomal protein catabolic process (GO:0010498)  SPSB3,BTBD6,RHBDD1,ANAPC16,TOPORS,SHARPIN,PMAI...
# negative regulation of nucleic acid-templated t...  CIC,IRF1,MTA3,PBXIP1,EHMT1,HMGA2,REST,NACC2,MP...
# positive regulation of gene expression (GO:0010...  WBP2,IRF1,DVL3,HMGA2,ACTA2,REST,KAT2B,RPS27L,E...
# peptidyl-lysine modification (GO:0018205)           PCNA,ATP7A,IVL,KAT2B,VCPKMT,TOPORS,SIRT3,SUMO1...
# positive regulation of multicellular organismal...  TGFBR1,INSL3,BMPR2,RPS19,IL33,FOXJ1,PPM1F,BAMB...
# positive regulation of transcription from RNA p...  WBP2,NR4A2,IRF1,ZNF76,GPRIN1,HMGA2,KAT2B,PIN1,...
# transmembrane transport (GO:0055085)                DMTN,ATP7A,SLC22A9,HTR3B,ATP1B1,ATP1A4,ATP6V1F...
# cellular response to DNA damage stimulus (GO:00...  CDKN1A,BTG2,BAX,ENDOV,PIDD1,RECQL,TOPORS,XPC,C...
# chemical synaptic transmission (GO:0007268)         GPRIN1,CNP,CACNB3,HTR3B,SCRIB,CHRNE,KCNC4,HTR1...
# regulation of phosphorylation (GO:0042325)          CDKN1A,ATP7A,BCL10,STAT2,FN1,NUP188,LDB1,ECD,E...
# plasma membrane bounded cell projection assembl...  DMTN,B9D2,BBS4,TCTEX1D2,FOXJ1,AIF1,ICK,TMEM67,...
# ubiquitin-dependent protein catabolic process (...  SPSB3,BTBD6,HACE1,NTAN1,ANAPC16,TOPORS,SHARPIN...
# cellular protein localization (GO:0034613)          BBS4,STX16-NPEPL1,PACS2,NACC2,RAB33B,RAB40C,RI...
# regulation of intracellular signal transduction...  ARAP2,EHMT1,PIN1,RMI2,NLRP13,CEACAM1,PTPN22,UB...
# positive regulation of transcription, DNA-templ...  WBP2,NR4A2,IRF1,DVL3,ZNF76,GPRIN1,HMGA2,REST,K...
# cilium assembly (GO:0060271)                        B9D2,BBS4,BBOF1,DYNLRB1,HSPB11,TCTEX1D2,CCDC13...
# regulation of gene expression (GO:0010468)          MLF2,ZNF2,ZNF655,HMGA2,ACTA2,REST,ZNF630,ZNF83...
# organelle assembly (GO:0070925)                     B9D2,BBS4,PACS2,STARD9,TCTEX1D2,VPS4A,FOXJ1,AT...
# regulation of cellular macromolecule biosynthet...  MLF2,ZNF2,ZNF655,HMGA2,REST,ZNF630,ZNF83,TGFBR...
# regulation of cell proliferation (GO:0042127)       CDKN1A,IRF1,BTG2,CCPG1,ITGAV,TSPAN31,CAPNS1,RE...
# negative regulation of cellular macromolecule b...  CIC,IRF1,BTG2,MTA3,PBXIP1,EHMT1,HMGA2,REST,NAC...
# positive regulation of nucleic acid-templated t...  WBP2,IRF1,DVL3,HMGA2,REST,TGFBR1,BCL10,KLF4,IN...
# vesicle-mediated transport (GO:0016192)             ARAP2,ACAP2,STX16-NPEPL1,SFT2D2,MICALL1,EEA1,W...
# regulation of transcription, DNA-templated (GO:...  WBP2,CIC,MLF2,CDKN1A,IRF1,MTA3,CDT1,RFX7,DVL3,...
# endosomal transport (GO:0016197)                    MICALL1,EEA1,WASH3P,HOOK2,VPS4A,DENND1C,RIC1,D...
#
# [101 rows x 7 columns]

# %%
#create a heatmap of the gene expression so we can visualize these differences
deg_adata = adata[:, list(highly_deg2.keys())]

from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=500, facecolor='w', edgecolor='k')
plt.imshow(deg_adata.X.T)
plt.show()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 120 × 54675
#     obs: 'cellline', 'replicate', 'timepoint', 'treatment'

# %%
from sklearn.svm import SVR
clf = SVR(gamma='scale', C=1.0, epsilon=0.2)
clf.fit(np.array(adata.X), np.array([int(x) for x in adata.obs["cellline"].values]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-4dcb73cb7fc7> in <module>()
#       1 from sklearn.svm import SVR
#       2 clf = SVR(gamma='scale', C=1.0, epsilon=0.2)
# ----> 3 clf.fit(np.array(adata.X), np.array([int(x) for x in adata.obs["cellline"].values]))
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# sklearn/svm/libsvm.pyx in sklearn.svm.libsvm.fit()
#
# TypeError: must be real number, not str

# %%
adata.X
# Out:
# array([[ 9.61412  , 11.288549 ,  7.5323133, ...,  3.15335  ,  4.207523 ,
#          3.8651178],
#        [ 9.317007 , 11.1318245,  7.3110266, ...,  3.1582482,  4.1906314,
#          3.9345956],
#        [ 9.5570545, 11.149244 ,  7.4296546, ...,  3.0420399,  4.3473134,
#          4.2384768],
#        ...,
#        [ 8.332385 , 10.834907 ,  7.3240075, ...,  2.8425329,  3.577644 ,
#          3.3269353],
#        [ 8.404764 , 10.54375  ,  7.444113 , ...,  2.7438347,  3.4016907,
#          3.3246932],
#        [ 8.337829 , 10.586966 ,  7.350737 , ...,  2.792215 ,  3.611557 ,
#          3.3361006]], dtype=float32)

# %%
line_4_treated = filter_adata(adata, [("cellline", "4"), ("treatment", "treated")])
line_5_treated = filter_adata(adata, [("cellline", "5"), ("treatment", "treated")])
line_16_treated = filter_adata(adata, [("cellline", "16"), ("treatment", "treated")])
line_13_treated = filter_adata(adata, [("cellline", "13"), ("treatment", "treated")])

# %%
# from matplotlib.pyplot import figure
# figure(num=None, figsize=(8, 6), dpi=500, facecolor='w', edgecolor='k')

fig, ax = plt.subplots(figsize=(18, 6))
ax.imshow(adata.X, interpolation='nearest')
ax.set_aspect('auto')
plt.show()

# %% [markdown]
# All of the genes, ordered by probeset with no clustering. Let's try some hierarchical clustering:

# %%
adata.X.shape[1]
# Out:
# 54675

# %%
x[1].shape
# Out:
# (54675,)

# %%
x = adata.X.T
l = x.shape[0]
D = scipy.zeros([l, l])
print ("calculating pairwise distance...")
for i in range(l):
    for j in range(l):
        D[i,j] = scipy.spatial.distance.euclidean(x[i], x[j]) #euclidean distance - this takes like an hour, rip
print ("completed distance calculation")
        
# Compute and plot dendrogram.
fig = pylab.figure()
axdendro = fig.add_axes([0.09,0.1,0.2,0.8]) #?
Y = sch.linkage(D, method='centroid')
Z = sch.dendrogram(Y, orientation='right')
axdendro.set_xticks([])
axdendro.set_yticks([])

# Plot distance matrix.
axmatrix = fig.add_axes([0.3,0.1,0.6,0.8])
index = Z['leaves']
D = D[index,:]
D = D[:,index]
im = axmatrix.matshow(D, aspect='auto', origin='lower')
axmatrix.set_xticks([])
axmatrix.set_yticks([])

# Plot colorbar.
axcolor = fig.add_axes([0.91,0.1,0.02,0.8])
pylab.colorbar(im, cax=axcolor)

# Display and sav
fig.show()
# Out:
# starting distance calculation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ea1784093d52> in <module>()
#       5 for i in range(l):
#       6     for j in range(l):
# ----> 7         D[i,j] = scipy.spatial.distance.euclidean(x[i], x[j]) #euclidean distance
#       8 print ("completed distance calculation")
#       9
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/scipy/spatial/distance.py in euclidean(u, v, w)
#     551
#     552     """
# --> 553     return minkowski(u, v, p=2, w=w)
#     554
#     555
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/scipy/spatial/distance.py in minkowski(u, v, p, w)
#     479             root_w = np.power(w, 1/p)
#     480         u_v = root_w * u_v
# --> 481     dist = norm(u_v, ord=p)
#     482     return dist
#     483
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#    1229     """
#    1230     a = asarray(a, dtype=dtype, order=order)
# -> 1231     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1232         raise ValueError(
#    1233             "array must not contain infs or NaNs")
#
# /home/software/python/python-3.6.4/lib/python3.6/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      39
#      40 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 41     return umr_all(a, axis, dtype, out, keepdims)
#      42
#      43 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:

# %%
for label in ["treated", "untreated"]:
    for cl in celllines:
        line = filter_adata(adata, [("cellline", cl), ("treatment", label)])
        print (cl, label)
        plt.imshow(line.X[:, :100])
        plt.show()
# Out:
# 4 treated
# 5 treated
# 13 treated
# 16 treated
# 4 untreated
# 5 untreated
# 13 untreated
# 16 untreated

# %% [markdown]
# ## Cluster Analysis with Scanpy

# %%
adata.obs["timepoint"] = [int(c.split("_")[2]) for c in adata.obs_names]

# %%
sc.tl.pca(adata)
sc.pl.pca(adata, color=["cellline", "replicate", "timepoint", "treatment"])

# %% [markdown]
# TODO: Deconvolve the above plots so that you can see the trajectories of each replicate*cellline over time
#
# It seems like from this that I should use replicate2.

# %%
sc.pl.pca_loadings(adata)

# %% [markdown]
# #### Finding differentially expressed genes by t-test

# %%
sc.tl.rank_genes_groups(adata, groupby = "treatment", reference = "untreated", groups=["untreated", "treated"], method="logreg", n_genes = 1000)

# %%
sc.pl.rank_genes_groups(adata)

# %%
#gather into an anndata so we can move it around easily
adata = anndata.AnnData(all_celllines.T)
adata.obs["cellline"] = [c.split("_")[0] for c in adata.obs_names]
adata.obs["replicate"] = [c.split("_")[1] for c in adata.obs_names]
adata.obs["timepoint"] = [c.split("_")[2] for c in adata.obs_names]
adata.obs["treatment"] = [c.split("_")[3] for c in adata.obs_names]
adata
# Out:
# AnnData object with n_obs × n_vars = 112 × 54675
#     obs: 'cellline', 'replicate', 'timepoint', 'treatment'

# %%
upregulated = [x[0] for x in list(adata.uns['rank_genes_groups']['names'])]
# downregulated = [x[3] for x in list(adata.uns['rank_genes_groups']['names'])]
overlap(upregulated, chandni_anova_probes)
# overlap(downregulated, chandni_anova_probes)
# Out:
# 28

# %%
rep2_treated = filter_adata(adata, [("replicate", "2"), ("treatment", "treated")])
rep2_untreated = filter_adata(adata, [("replicate", "2"), ("treatment", "treated")])
gene_heatmap(rep2_treated, upregulated)
gene_heatmap(rep2_untreated, upregulated)

# %% [markdown]
# ## Analysis of ANOVA Results

# %% [markdown]
# ANOVA is run in a separate notebook.

# %% [markdown]
# ### ANOVA values from Chandni

# %%
import scipy.io
matrix = scipy.io.loadmat("ComputationalAnalyses/ANOVA/ExpData.mat")
matrix
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Sun Aug 22 20:41:46 2010',
#  '__version__': '1.0',
#  '__globals__': [],
#  'ExpData': array([[(array([[array(['discoidin domain receptor tyrosine kinase 1, DDR1'], dtype='<U49')],
#         [array(['replication factor C (activator 1) 2, 40kDa, RFC2'], dtype='<U49')],
#         [array(["heat shock 70kDa protein 6 (HSP70B'), HSPA6"], dtype='<U43')],
#         ...,
#         [array([], dtype='<U1')],
#         [array([], dtype='<U1')],
#         [array([], dtype='<U1')]], dtype=object), array([[array(['1007_s_at'], dtype='<U9')],
#         [array(['1053_at'], dtype='<U7')],
#         [array(['117_at'], dtype='<U6')],
#         ...,
#         [array(['AFFX-r2-Ec-bioD-5_at'], dtype='<U20')],
#         [array(['AFFX-r2-P1-cre-3_at'], dtype='<U19')],
#         [array(['AFFX-r2-P1-cre-5_at'], dtype='<U19')]], dtype=object), array([[(array([[(array([[(array([[  591.11717433,   791.83646587],
#         [ 1605.31457895,  1524.52246673],
#         [  148.68898449,   196.69868375],
#         ...,
#         [11814.90690356, 11459.99400088],
#         [27767.86729256, 28875.68678752],
#         [25970.51900088, 27298.54359663]]), array([[  575.91177058,   509.89292369],
#         [ 2012.43739811,  1626.80014691],
#         [  136.40474684,   143.47975579],
#         ...,
#         [11032.89236845, 11226.06592223],
#         [29402.75233421, 29858.09476929],
#         [25978.24049352, 27220.07161667]]), array([[  650.37189319,   644.81537859],
#         [ 1790.55813323,  1771.96151186],
#         [  110.83790227,   115.9855296 ],
#         ...,
#         [ 9648.58167642, 11274.4559072 ],
#         [28830.34497748, 30502.58456219],
#         [26260.23166746, 28078.4397224 ]]), array([[  579.69712162,   636.19515856],
#         [ 1810.61507993,  1863.5505708 ],
#         [  121.83436194,   140.26347757],
#         ...,
#         [11180.27259746, 11390.67400373],
#         [27301.66623552, 29393.701064  ],
#         [24394.15913728, 27890.3003503 ]]), array([[  550.51189077,   582.3144129 ],
#         [ 1933.87021799,  1880.71775486],
#         [  122.42026346,   145.07089267],
#         ...,
#         [10958.74015101, 11226.06592223],
#         [28844.34400088, 30502.58456219],
#         [26696.86537311, 28670.28833901]]), array([[  497.28473247,   542.13404151],
#         [ 1972.33169042,  1768.89766137],
#         [  108.82568303,   163.88109197],
#         ...,
#         [10707.814354  , 10496.41578143],
#         [29042.26900088, 28029.55315156],
#         [25511.1616102 , 25562.25691971]]), array([[  546.12335158,   479.56641294],
#         [ 1852.09320825,  1544.32722667],
#         [  137.36597521,   115.02823484],
#         ...,
#         [11307.38858812, 12153.14816754],
#         [27848.37733421, 31104.3944857 ],
#         [25854.45914878, 29015.619378  ]]), array([[  679.45171167,   575.59586163],
#         [ 1511.49599255,  1367.13704351],
#         [  196.25894989,   189.05583495],
#         ...,
#         [10560.05501283, 10813.28322579],
#         [26864.387183  , 28219.68320095],
#         [24829.13477672, 27059.44400088]]))]],
#        dtype=[('log', 'O'), ('t4h', 'O'), ('t8h', 'O'), ('t12h', 'O'), ('t24h', 'O'), ('t36h', 'O'), ('t48h', 'O'), ('t72h', 'O')]), array([[(array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         ...,
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#         [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#        dtype=object))]],
#        dtype=[('log', 'O'), ('t4h', 'O'), ('t8h', 'O'), ('t12h', 'O'), ('t24h', 'O'), ('t36h', 'O'), ('t48h', 'O'), ('t72h', 'O')]))]],
#         [44602],
#         [44610],
#         [44675],
#         [44701],
#         [44710],
#         [44752],
#         [44784],
#         [44795],
#         [44821],
#         [44877],
#         [44909],
#         [44948],
#         [44965],
#         [45013],
#         [45026],
#         [45107],
#         [45116],
#         [45174],
#         [45203],
#         [45286],
#         [45305],
#         [45316],
#         [45351],
#         [45425],
#         [45495],
#         [45523],
#         [45580],
#         [45609],
#         [45719],
#         [45762],
#         [45824],
#         [45891],
#         [45932],
#         [46132],
#         [46250],
#         [46313],
#         [46406],
#         [46473],
#         [46479],
#         [46491],
#         [46543],
#         [46714],
#         [46805],
#         [46866],
#         [46915],
#         [46951],
#         [46987],
#         [47141],
#         [47321],
#         [47384],
#         [47682],
#         [47704],
#         [47742],
#         [47809],
#         [47840],
#         [47872],
#         [47971],
#         [47983],
#         [48262],
#         [48317],
#         [48386],
#         [48528],
#         [48582],
#         [48589],
#         [48721],
#         [48753],
#         [48832],
#         [48835],
#         [48947],
#         [49074],
#         [49122],
#         [49193],
#         [49238],
#         [49308],
#         [49349],
#         [49502],
#         [49603],
#         [49604],
#         [49663],
#         [49703],
#         [49747],
#         [49997],
#         [50075],
#         [50392],
#         [50443],
#         [50584],
#         [50614],
#         [50670],
#         [50796],
#         [50975],
#         [51059],
#         [51193],
#         [51273],
#         [51306],
#         [51338],
#         [51391],
#         [51579],
#         [51615],
#         [51622],
#         [51650],
#         [51907],
#         [52207],
#         [52228],
#         [52337],
#         [52349],
#         [52510],
#         [52614],
#         [52754],
#         [52765],
#         [53093],
#         [53291],
#         [53325],
#         [53373],
#         [53591],
#         [53860],
#         [53867],
#         [53919],
#         [54021],
#         [54232],
#         [54285],
#         [54287],
#         [54293],
#         [54338],
#         [54436],
#         [54437],
#         [54476],
#         [54492]], dtype=uint16))]],
#        dtype=[('trt', 'O'), ('time', 'O'), ('sens', 'O'), ('trtXtime', 'O'), ('trtXsens', 'O'), ('timeXsens', 'O'), ('trtXtimeXsens', 'O'), ('trtXsensORall', 'O'), ('trtXsensORall_P', 'O')]), array([[[ 591.11717433,  981.25265485,  446.31580397, ...,
#            981.25265485,  446.31580397,  420.13857867],
#          [ 791.83646587,  883.146118  ,  385.41527937, ...,
#            883.146118  ,  385.41527937,  665.78566154],
#          [ 575.91177058,  792.60847063,  332.55523511, ...,
#            639.39266012,  347.92305426,  277.35109736],
#          ...,
#          [ 479.56641294,  720.1233176 ,  315.14885166, ...,
#           1181.79707399,  364.64062171,  379.57501454],
#          [ 679.45171167, 1113.4155779 ,  530.95441781, ...,
#           1393.35908751,  665.26071928,  537.66480206],
#          [ 575.59586163, 1098.17431603,  387.58894028, ...,
#           1339.56892392,  369.45659109,  464.67770249]],
#
#         [[ 289.9041421 ,  231.19782192,  213.32071126, ...,
#            231.19782192,  213.32071126,  240.63399056],
#          [ 338.10376088,  301.63639973,  224.25891857, ...,
#            301.63639973,  224.25891857,  232.46681836],
#          [ 242.93666246,  254.0679591 ,  192.06608902, ...,
#            237.42527987,  212.99421318,  247.97009593],
#          ...,
#           30551.67733421, 29796.9531664 , 30522.27841207],
#          [26864.387183  , 30686.78988671, 30199.57022185, ...,
#           31042.17627446, 29891.92112989, 26467.20981544],
#          [28219.68320095, 30158.73341473, 29782.34501487, ...,
#           29891.92112989, 29925.12345391, 28763.22315681]],
#
#         [[25970.51900088, 29013.35921246, 30152.99400088, ...,
#           29013.35921246, 30152.99400088, 26736.72539597],
#          [27298.54359663, 29201.82587003, 27598.12313887, ...,
#           29201.82587003, 27598.12313887, 25791.36627387],
#          [25978.24049352, 28692.35351615, 30070.51444702, ...,
#           29655.64400088, 29932.01533982, 27847.18565748],
#          ...,
#          [29015.619378  , 29115.52329159, 27880.55692623, ...,
#           26995.07940352, 27847.82276358, 29386.17248305],
#          [24829.13477672, 29996.24729618, 28931.23493067, ...,
#           29996.24729618, 28700.14703372, 24779.31313188],
#          [27059.44400088, 28460.64879193, 27383.27705422, ...,
#           28478.85054133, 25710.07694205, 25133.55416247]]]))]],
#        dtype=[('Description', 'O'), ('ProbesetID', 'O'), ('C4', 'O'), ('C5', 'O'), ('C16', 'O'), ('C13', 'O'), ('Pmatrix', 'O'), ('Psum', 'O'), ('IND_P', 'O'), ('Pvalues', 'O'), ('ANOVA3', 'O'), ('prunedExpMat', 'O'), ('ExpMat', 'O')])}

# %% [markdown]
# Format is a 3-D array (probably 1 replicate), with time (8? 7?), sensitivity(2), treatment(2), celllines(4)

# %%
np.array(matrix["ExpData"][0][0][2])
# Out:
# array([[(array([[(array([[(array([[  591.11717433,   791.83646587],
#        [ 1605.31457895,  1524.52246673],
#        [  148.68898449,   196.69868375],
#        ...,
#        [11814.90690356, 11459.99400088],
#        [27767.86729256, 28875.68678752],
#        [25970.51900088, 27298.54359663]]), array([[  575.91177058,   509.89292369],
#        [ 2012.43739811,  1626.80014691],
#        [  136.40474684,   143.47975579],
#        ...,
#        [11032.89236845, 11226.06592223],
#        [29402.75233421, 29858.09476929],
#        [25978.24049352, 27220.07161667]]), array([[  650.37189319,   644.81537859],
#        [ 1790.55813323,  1771.96151186],
#        [  110.83790227,   115.9855296 ],
#        ...,
#        [ 9648.58167642, 11274.4559072 ],
#        [28830.34497748, 30502.58456219],
#        [26260.23166746, 28078.4397224 ]]), array([[  579.69712162,   636.19515856],
#        [ 1810.61507993,  1863.5505708 ],
#        [  121.83436194,   140.26347757],
#        ...,
#        [11180.27259746, 11390.67400373],
#        [27301.66623552, 29393.701064  ],
#        [24394.15913728, 27890.3003503 ]]), array([[  550.51189077,   582.3144129 ],
#        [ 1933.87021799,  1880.71775486],
#        [  122.42026346,   145.07089267],
#        ...,
#        [10958.74015101, 11226.06592223],
#        [28844.34400088, 30502.58456219],
#        [26696.86537311, 28670.28833901]]), array([[  497.28473247,   542.13404151],
#        [ 1972.33169042,  1768.89766137],
#        [  108.82568303,   163.88109197],
#        ...,
#        [10707.814354  , 10496.41578143],
#        [29042.26900088, 28029.55315156],
#        [25511.1616102 , 25562.25691971]]), array([[  546.12335158,   479.56641294],
#        [ 1852.09320825,  1544.32722667],
#        [  137.36597521,   115.02823484],
#        ...,
#        [11307.38858812, 12153.14816754],
#        [27848.37733421, 31104.3944857 ],
#        [25854.45914878, 29015.619378  ]]), array([[  679.45171167,   575.59586163],
#        [ 1511.49599255,  1367.13704351],
#        [  196.25894989,   189.05583495],
#        ...,
#        [10560.05501283, 10813.28322579],
#        [26864.387183  , 28219.68320095],
#        [24829.13477672, 27059.44400088]]))]],
#       dtype=[('log', 'O'), ('t4h', 'O'), ('t8h', 'O'), ('t12h', 'O'), ('t24h', 'O'), ('t36h', 'O'), ('t48h', 'O'), ('t72h', 'O')]), array([[(array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object))]],
#       dtype=[('log', 'O'), ('t4h', 'O'), ('t8h', 'O'), ('t12h', 'O'), ('t24h', 'O'), ('t36h', 'O'), ('t48h', 'O'), ('t72h', 'O')]))]],
#       dtype=[('Exp', 'O'), ('Presence', 'O')]), array([[(array([[(array([[  591.11717433,   791.83646587],
#        [ 1605.31457895,  1524.52246673],
#        [  148.68898449,   196.69868375],
#        ...,
#        [11814.90690356, 11459.99400088],
#        [27767.86729256, 28875.68678752],
#        [25970.51900088, 27298.54359663]]), array([[  485.40103832,   485.89725724],
#        [ 1829.92738491,  1613.26158785],
#        [  111.54478309,   194.72444516],
#        ...,
#        [11202.24032004, 11397.30986186],
#        [28258.74400088, 30826.846957  ],
#        [25196.50233421, 29067.40650788]]), array([[  873.38551363,   752.42398825],
#        [ 1835.5084886 ,  1744.65631682],
#        [  150.64865407,   110.88635851],
#        ...,
#        [ 9603.65118922, 11143.82733421],
#        [28908.8750058 , 31026.61086785],
#        [25440.41721773, 28172.19001556]]), array([[  777.40611232,   813.2880961 ],
#        [ 1963.72385069,  1969.53801041],
#        [  123.80746261,   127.14000284],
#        ...,
#        [11329.70424746, 11201.62301779],
#        [27729.26900088, 29158.10233421],
#        [25445.25938049, 28630.32139807]]), array([[ 1034.89227557,  1225.06318657],
#        [ 2096.91406964,  1766.212326  ],
#        [  140.14375738,   122.98055126],
#        ...,
#        [10721.40111196, 11251.90556423],
#        [27995.42733421, 30657.73426236],
#        [24286.31097499, 29040.53441168]]), array([[ 1104.40225334,  1430.67244659],
#        [ 1837.90759663,  1537.59287647],
#        [  127.63048806,   124.68909651],
#        ...,
#        [11472.35365246, 10972.54522112],
#        [28238.51332207, 28844.34400088],
#        [26135.61891808, 27305.58753916]]), array([[  984.12516825,  1610.81727956],
#        [ 1472.11231458,  1507.12431409],
#        [  140.90662484,   130.25220961],
#        ...,
#        [10628.89211312, 10659.08150088],
#        [25622.30124254, 29916.46900088],
#        [23768.12663373, 27297.65833172]]), array([[  869.51932139,  1219.12401089],
#        [ 1853.3900213 ,  1433.81868331],
#        [  116.677034  ,   102.37912384],
#        ...,
#        [11588.89907081, 12785.90912022],
#        [27729.26900088, 29916.46900088],
#        [25697.72247739, 29610.10508983]]))]],
#       dtype=[('log', 'O'), ('t4h', 'O'), ('t8h', 'O'), ('t12h', 'O'), ('t24h', 'O'), ('t36h', 'O'), ('t48h', 'O'), ('t72h', 'O')]), array([[(array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object), array([[array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        ...,
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')],
#        [array(['P'], dtype='<U1'), array(['P'], dtype='<U1')]],
#       dtype=object))]],
#       dtype=[('log', 'O'), ('t4h', 'O'), ('t8h', 'O'), ('t12h', 'O'), ('t24h', 'O'), ('t36h', 'O'), ('t48h', 'O'), ('t72h', 'O')]))]],
#       dtype=[('Exp', 'O'), ('Presence', 'O')]))]],
#       dtype=[('Untreated', 'O'), ('Treated', 'O')])

# %% [markdown]
# Hmm... these values look nothing like mine, they're too large?

# %% [markdown]
# ### Replicate 1 results
